# %%
import requests
from bs4 import BeautifulSoup

# URL do site alvo
url = "https://unsplash.com/pt-br/s/fotografias/cachorro"

# Realizar a requisição GET para obter o conteúdo da página
response = requests.get(url)

# Verificar se a requisição foi bem-sucedida
if response.status_code == 200:
    # Criar um objeto BeautifulSoup com o conteúdo HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todos os elementos que contêm informações dos produtos
    products = soup.find_all("div", class_="thumbnail")

    # Iterar sobre os elementos dos produtos e extrair as informações desejadas
    for imagem in imagens:
    
        # Link do produto
         imagem_link  = imagens.find("a", class_="WxXo")["href"]
        
        # Exibir as informações do produto

        print("Link:", link)
else:
    print("Falha ao acessar o site:", response.status_code)
# Out:
#   File <tokenize>:26
#     print("Link:", link)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import requests
from bs4 import BeautifulSoup

# URL do site alvo
url = "https://unsplash.com/pt-br/s/fotografias/cachorro"

# Realizar a requisição GET para obter o conteúdo da página
response = requests.get(url)

# Verificar se a requisição foi bem-sucedida
if response.status_code == 200:
    # Criar um objeto BeautifulSoup com o conteúdo HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todos os elementos que contêm informações das imagens
    imagens = soup.find_all("img")

    # Iterar sobre os elementos das imagens e extrair os links
    for i, imagem in enumerate(imagens):
        # Link da imagem
        imagem_link = imagem["src"]
        
        # Exibir as informações da imagem
        print(f"Link da imagem {i+1}: {imagem_link}")
else:
    print("Falha ao acessar o site:", response.status_code)
# Out:
# Link da imagem 1: https://media.istockphoto.com/id/1853686056/pt/foto/golden-retriever-relaxing-at-home.webp?b=1&s=170667a&w=0&k=20&c=s75WnAIV-XTaHxRozy4OZzwk6mnVL_r_T2aqheJKXy4=
# Link da imagem 2: https://media.istockphoto.com/id/1503385646/pt/foto/portrait-funny-and-happy-shiba-inu-puppy-dog-peeking-out-from-behind-a-blue-banner-isolated-on.webp?b=1&s=170667a&w=0&k=20&c=wpVvn3Jq9NuaTCckdBjbkKOcwlsUIYST8qAUcNGKerc=
# Link da imagem 3: https://media.istockphoto.com/id/1652227141/pt/foto/running-fluffy-pembroke-welsh-corgi-puppy.webp?b=1&s=170667a&w=0&k=20&c=cak_b3SRoMzFCQVBULjCfYxFwcrcqHax-i71vzE4XX4=
# Link da imagem 4: https://media.istockphoto.com/id/1491278980/pt/foto/english-setters-playing-vestfold-norway.webp?b=1&s=170667a&w=0&k=20&c=Nvfh-OSCsBaSTtGxE5uVpo9gq3Qj_l5_xdDoT9xZUCc=
# Link da imagem 5: https://media.istockphoto.com/id/1501348253/pt/foto/golden-retriever-and-british-shorthair-cat-lying-together-under-blanket.webp?b=1&s=170667a&w=0&k=20&c=CSFgixATT-J7_LviEKQTgK-savfz-s3MAiIXFpQ8RAk=
# Link da imagem 6: https://media.istockphoto.com/id/1589824836/pt/foto/cute-brown-dog-that-smiles-isolated-background.webp?b=1&s=170667a&w=0&k=20&c=fd6CGAswV_XrCCKic9EwIa3E7hLsZGM0xOR4K2NvmF4=
# Link da imagem 168: https://media.istockphoto.com/id/1516239450/pt/foto/love-portrait-and-family-with-dog-at-animal-shelter-for-adoption-at-kennel.webp?b=1&s=170667a&w=0&k=20&c=A5EuGIgKZ--vGui2MzHZcTGXAW-AOT3s4fPyYc2w36o=
# Link da imagem 169: https://media.istockphoto.com/id/1702690159/pt/foto/dog-and-cat-friendship.webp?b=1&s=170667a&w=0&k=20&c=9hrn9F1vw3yAnBNqQYW9KTmKRzcOuXd1bcObwQdk_NY=
# Link da imagem 170: https://media.istockphoto.com/id/1482780941/pt/foto/scared-dog-is-hiding-under-the-bed-at-home.webp?b=1&s=170667a&w=0&k=20&c=CSUewdYfZmlfD2MoCjXbjBcoeQHdntwm2TCf8RBSs_k=
# Link da imagem 171: https://media.istockphoto.com/id/1497909628/pt/foto/cat-and-dog-sitting-together-on-meadow.webp?b=1&s=170667a&w=0&k=20&c=zp7EGJtL0yyQI3eJUCWzqYqQUpYz1bJi6GydANN2voY=
# Link da imagem 172: https://media.istockphoto.com/id/1989566463/pt/foto/dog-person-and-hand-point-for-discipline-on-apartment-sofa-for-behaviour-warning-command-or.webp?b=1&s=170667a&w=0&k=20&c=_dnRGd-k1rwsLcrnxJBNDmATJwl5wpTlsyYrd_I5d64=
# Link da imagem 173: https://secure.insightexpressai.com/adServer/adServerESI.aspx?script=false&bannerID=11757573&rnd=1713391129776&redir=https://secure.insightexpressai.com/adserver/1pixel.gif
# Link da imagem 174: https://secure.insightexpressai.com/adServer/adServerESI.aspx?script=false&bannerID=11758046&rnd=1713391129776&redir=https://secure.insightexpressai.com/adserver/1pixel.gif
# Link da imagem 175: https://secure-gl.imrworldwide.com/cgi-bin/m?ca=nlsn530690&cr=crtve&ce=nielsen&pc=nielsen_plc0001&ci=nlsnci2891&am=3&at=view&rt=banner&st=image&r=1713391129776

# %%
import os
import requests
from bs4 import BeautifulSoup
import shutil

# URL do site alvo
url = "https://unsplash.com/pt-br/s/fotografias/cachorro"

# Pasta onde as imagens serão salvas
diretorio_destino = "imagens_cachorros"

# Criar o diretório de destino se ele não existir
if not os.path.exists(diretorio_destino):
    os.makedirs(diretorio_destino)

# Realizar a requisição GET para obter o conteúdo da página
response = requests.get(url)

# Verificar se a requisição foi bem-sucedida
if response.status_code == 200:
    # Criar um objeto BeautifulSoup com o conteúdo HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todos os elementos que contêm informações das imagens
    imagens = soup.find_all("img")

    # Iterar sobre os elementos das imagens e extrair os links
    for i, imagem in enumerate(imagens):
        # Link da imagem
        imagem_link = imagem["src"]
        
        # Fazer o download da imagem
        response_imagem = requests.get(imagem_link, stream=True)
        
        # Verificar se o download foi bem-sucedido
        if response_imagem.status_code == 200:
            # Caminho onde a imagem será salva
            caminho_imagem = os.path.join(diretorio_destino, f"imagem_{i+1}.jpg")
            
            # Salvar a imagem no diretório destino
            with open(caminho_imagem, 'wb') as arquivo:
                response_imagem.raw.decode_content = True
                shutil.copyfileobj(response_imagem.raw, arquivo)
            
            print(f"Imagem {i+1} salva com sucesso.")
        else:
            print(f"Falha ao fazer o download da imagem {i+1}")
else:
    print("Falha ao acessar o site:", response.status_code)
# Out:
# Imagem 1 salva com sucesso.
# Imagem 2 salva com sucesso.
# Imagem 3 salva com sucesso.
# Imagem 4 salva com sucesso.
# Imagem 5 salva com sucesso.
# Imagem 6 salva com sucesso.
# Imagem 7 salva com sucesso.
# Imagem 8 salva com sucesso.
# Imagem 9 salva com sucesso.
# Imagem 10 salva com sucesso.
# Imagem 11 salva com sucesso.
# Imagem 12 salva com sucesso.
# Imagem 13 salva com sucesso.
# Imagem 14 salva com sucesso.
# Imagem 15 salva com sucesso.
# Imagem 16 salva com sucesso.
# Imagem 17 salva com sucesso.
# Imagem 18 salva com sucesso.
# Imagem 19 salva com sucesso.
# Imagem 20 salva com sucesso.
# Imagem 21 salva com sucesso.
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[15], line 33
#      30 imagem_link = imagem["src"]
#      32 # Fazer o download da imagem
# ---> 33 response_imagem = requests.get(imagem_link, stream=True)
#      35 # Verificar se o download foi bem-sucedido
#      36 if response_imagem.status_code == 200:
#      37     # Caminho onde a imagem será salva
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\sessions.py:695, in Session.send(self, request, **kwargs)
#     692 hooks = request.hooks
#     694 # Get the appropriate adapter to use
# --> 695 adapter = self.get_adapter(url=request.url)
#     697 # Start time (approximately) of the request
#     698 start = preferred_clock()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\sessions.py:792, in Session.get_adapter(self, url)
#     789         return adapter
#     791 # Nothing matches :-/
# --> 792 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for '...'

# %%
import os
import requests
from bs4 import BeautifulSoup
import shutil
from urllib.parse import urlparse

# URL do site alvo
url = "https://unsplash.com/pt-br/s/fotografias/cachorro"

# Pasta onde as imagens serão salvas
diretorio_destino = "imagens_cachorros"

# Criar o diretório de destino se ele não existir
if not os.path.exists(diretorio_destino):
    os.makedirs(diretorio_destino)

# Realizar a requisição GET para obter o conteúdo da página
response = requests.get(url)

# Verificar se a requisição foi bem-sucedida
if response.status_code == 200:
    # Criar um objeto BeautifulSoup com o conteúdo HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todos os elementos que contêm informações das imagens
    imagens = soup.find_all("img")

    # Iterar sobre os elementos das imagens e extrair os links
    for i, imagem in enumerate(imagens):
        # Link da imagem
        imagem_link = imagem["src"]
        
        # Verificar se o link é uma URL HTTP ou HTTPS
        if imagem_link.startswith("http://") or imagem_link.startswith("https://"):
            # Fazer o download da imagem
            response_imagem = requests.get(imagem_link, stream=True)
            
            # Verificar se o download foi bem-sucedido
            if response_imagem.status_code == 200:
                # Caminho onde a imagem será salva
                caminho_imagem = os.path.join(diretorio_destino, f"imagem_{i+1}.jpg")
                
                # Salvar a imagem no diretório destino
                with open(caminho_imagem, 'wb') as arquivo:
                    response_imagem.raw.decode_content = True
                    shutil.copyfileobj(response_imagem.raw, arquivo)
                
                print(f"Imagem {i+1} salva com sucesso.")
            else:
                print(f"Falha ao fazer o download da imagem {i+1}")
else:
    print("Falha ao acessar o site:", response.status_code)
# Out:
# Imagem 1 salva com sucesso.
# Imagem 2 salva com sucesso.
# Imagem 3 salva com sucesso.
# Imagem 4 salva com sucesso.
# Imagem 5 salva com sucesso.
# Imagem 6 salva com sucesso.
# Imagem 7 salva com sucesso.
# Imagem 8 salva com sucesso.
# Imagem 9 salva com sucesso.
# Imagem 10 salva com sucesso.
# Imagem 11 salva com sucesso.
# Imagem 12 salva com sucesso.
# Imagem 13 salva com sucesso.
# Imagem 14 salva com sucesso.
# Imagem 15 salva com sucesso.
# Imagem 16 salva com sucesso.
# Imagem 17 salva com sucesso.
# Imagem 18 salva com sucesso.
# Imagem 19 salva com sucesso.
# Imagem 20 salva com sucesso.
# Imagem 21 salva com sucesso.
# Imagem 23 salva com sucesso.
# Imagem 24 salva com sucesso.
# Imagem 26 salva com sucesso.
# Imagem 27 salva com sucesso.
# Imagem 29 salva com sucesso.
# Imagem 30 salva com sucesso.
# Imagem 32 salva com sucesso.
# Imagem 33 salva com sucesso.
# Imagem 35 salva com sucesso.
# Imagem 36 salva com sucesso.
# Imagem 38 salva com sucesso.
# Imagem 39 salva com sucesso.
# Imagem 41 salva com sucesso.
# Imagem 42 salva com sucesso.
# Imagem 44 salva com sucesso.
# Imagem 45 salva com sucesso.
# Imagem 47 salva com sucesso.
# Imagem 48 salva com sucesso.
# Imagem 50 salva com sucesso.
# Imagem 51 salva com sucesso.
# Imagem 53 salva com sucesso.
# Imagem 54 salva com sucesso.
# Imagem 56 salva com sucesso.
# Imagem 57 salva com sucesso.
# Imagem 59 salva com sucesso.
# Imagem 60 salva com sucesso.
# Imagem 62 salva com sucesso.
# Imagem 63 salva com sucesso.
# Imagem 65 salva com sucesso.
# Imagem 66 salva com sucesso.
# Imagem 68 salva com sucesso.
# Imagem 69 salva com sucesso.
# Imagem 71 salva com sucesso.
# Imagem 72 salva com sucesso.
# Imagem 74 salva com sucesso.
# Imagem 75 salva com sucesso.
# Imagem 77 salva com sucesso.
# Imagem 78 salva com sucesso.
# Imagem 80 salva com sucesso.
# Imagem 82 salva com sucesso.
# Imagem 84 salva com sucesso.
# Imagem 86 salva com sucesso.
# Imagem 88 salva com sucesso.
# Imagem 90 salva com sucesso.
# Imagem 92 salva com sucesso.
# Imagem 94 salva com sucesso.
# Imagem 96 salva com sucesso.
# Imagem 98 salva com sucesso.
# Imagem 100 salva com sucesso.
# Imagem 102 salva com sucesso.
# Imagem 104 salva com sucesso.
# Imagem 106 salva com sucesso.
# Imagem 108 salva com sucesso.
# Imagem 110 salva com sucesso.
# Imagem 112 salva com sucesso.
# Imagem 114 salva com sucesso.
# Imagem 116 salva com sucesso.
# Imagem 118 salva com sucesso.
# Imagem 120 salva com sucesso.
# Imagem 122 salva com sucesso.
# Imagem 124 salva com sucesso.
# Imagem 126 salva com sucesso.
# Imagem 128 salva com sucesso.
# Imagem 130 salva com sucesso.
# Imagem 132 salva com sucesso.
# Imagem 134 salva com sucesso.
# Imagem 136 salva com sucesso.
# Imagem 138 salva com sucesso.
# Imagem 140 salva com sucesso.
# Imagem 142 salva com sucesso.
# Imagem 144 salva com sucesso.
# Imagem 146 salva com sucesso.
# Imagem 148 salva com sucesso.
# Imagem 150 salva com sucesso.
# Imagem 152 salva com sucesso.
# Imagem 154 salva com sucesso.
# Imagem 156 salva com sucesso.
# Imagem 158 salva com sucesso.
# Imagem 160 salva com sucesso.
# Imagem 161 salva com sucesso.
# Imagem 162 salva com sucesso.
# Imagem 163 salva com sucesso.
# Imagem 164 salva com sucesso.
# Imagem 165 salva com sucesso.
# Imagem 166 salva com sucesso.
# Imagem 167 salva com sucesso.
# Imagem 168 salva com sucesso.
# Imagem 169 salva com sucesso.
# Imagem 170 salva com sucesso.
# Imagem 171 salva com sucesso.
# Imagem 172 salva com sucesso.
# Imagem 173 salva com sucesso.
# Imagem 174 salva com sucesso.
# Imagem 175 salva com sucesso.

# %%
import os
import requests
from bs4 import BeautifulSoup
import wget

# URL do site alvo
url = "https://unsplash.com/pt-br/s/fotografias/cachorro"

# Pasta onde as imagens serão salvas
diretorio_destino = "imagens_cachorros_2"

# Criar o diretório de destino se ele não existir
if not os.path.exists(diretorio_destino):
    os.makedirs(diretorio_destino)

# Realizar a requisição GET para obter o conteúdo da página
response = requests.get(url)

# Verificar se a requisição foi bem-sucedida
if response.status_code == 200:
    # Criar um objeto BeautifulSoup com o conteúdo HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todos os elementos que contêm informações das imagens
    imagens = soup.find_all("img")

    # Iterar sobre os elementos das imagens e extrair os links
    for i, imagem in enumerate(imagens):
        # Link da imagem
        imagem_link = imagem["src"]
        
        # Verificar se o link é uma URL HTTP ou HTTPS
        if imagem_link.startswith("http://") or imagem_link.startswith("https://"):
            # Caminho onde a imagem será salva
            caminho_imagem = os.path.join(diretorio_destino, f"imagem_{i+1}.jpg")
            
            # Fazer o download da imagem usando wget
            wget.download(imagem_link, caminho_imagem)
            
            print(f"Imagem {i+1} salva com sucesso.")
else:
    print("Falha ao acessar o site:", response.status_code)
# Out:
# Imagem 1 salva com sucesso.
# Imagem 2 salva com sucesso.
# Imagem 3 salva com sucesso.
# Imagem 4 salva com sucesso.
# Imagem 5 salva com sucesso.
# Imagem 6 salva com sucesso.
# Imagem 7 salva com sucesso.
# Imagem 8 salva com sucesso.
# Imagem 9 salva com sucesso.
# Imagem 10 salva com sucesso.
# Imagem 11 salva com sucesso.
# Imagem 12 salva com sucesso.
# Imagem 13 salva com sucesso.
# Imagem 14 salva com sucesso.
# Imagem 15 salva com sucesso.
# Imagem 16 salva com sucesso.
# Imagem 17 salva com sucesso.
# Imagem 18 salva com sucesso.
# Imagem 19 salva com sucesso.
# Imagem 20 salva com sucesso.
# Imagem 21 salva com sucesso.
# Imagem 23 salva com sucesso.
# Imagem 24 salva com sucesso.
# Imagem 26 salva com sucesso.
# Imagem 27 salva com sucesso.
# Imagem 29 salva com sucesso.
# Imagem 30 salva com sucesso.
# Imagem 32 salva com sucesso.
# Imagem 33 salva com sucesso.
# Imagem 35 salva com sucesso.
# Imagem 36 salva com sucesso.
# Imagem 38 salva com sucesso.
# Imagem 39 salva com sucesso.
# Imagem 41 salva com sucesso.
# Imagem 42 salva com sucesso.
# Imagem 44 salva com sucesso.
# Imagem 45 salva com sucesso.
# Imagem 47 salva com sucesso.
# Imagem 48 salva com sucesso.
# Imagem 50 salva com sucesso.
# Imagem 51 salva com sucesso.
# Imagem 53 salva com sucesso.
# Imagem 54 salva com sucesso.
# Imagem 56 salva com sucesso.
# Imagem 57 salva com sucesso.
# Imagem 59 salva com sucesso.
# Imagem 60 salva com sucesso.
# Imagem 62 salva com sucesso.
# Imagem 63 salva com sucesso.
# Imagem 65 salva com sucesso.
# Imagem 66 salva com sucesso.
# Imagem 68 salva com sucesso.
# Imagem 69 salva com sucesso.
# Imagem 71 salva com sucesso.
# Imagem 72 salva com sucesso.
# Imagem 74 salva com sucesso.
# Imagem 75 salva com sucesso.
# Imagem 77 salva com sucesso.
# Imagem 78 salva com sucesso.
# Imagem 80 salva com sucesso.
# Imagem 82 salva com sucesso.
# Imagem 84 salva com sucesso.
# Imagem 86 salva com sucesso.
# Imagem 88 salva com sucesso.
# Imagem 90 salva com sucesso.
# Imagem 92 salva com sucesso.
# Imagem 94 salva com sucesso.
# Imagem 96 salva com sucesso.
# Imagem 98 salva com sucesso.
# Imagem 100 salva com sucesso.
# Imagem 102 salva com sucesso.
# Imagem 104 salva com sucesso.
# Imagem 106 salva com sucesso.
# Imagem 108 salva com sucesso.
# Imagem 110 salva com sucesso.
# Imagem 112 salva com sucesso.
# Imagem 114 salva com sucesso.
# Imagem 116 salva com sucesso.
# Imagem 118 salva com sucesso.
# Imagem 120 salva com sucesso.
# Imagem 122 salva com sucesso.
# Imagem 124 salva com sucesso.
# Imagem 126 salva com sucesso.
# Imagem 128 salva com sucesso.
# Imagem 130 salva com sucesso.
# Imagem 132 salva com sucesso.
# Imagem 134 salva com sucesso.
# Imagem 136 salva com sucesso.
# Imagem 138 salva com sucesso.
# Imagem 140 salva com sucesso.
# Imagem 142 salva com sucesso.
# Imagem 144 salva com sucesso.
# Imagem 146 salva com sucesso.
# Imagem 148 salva com sucesso.
# Imagem 150 salva com sucesso.
# Imagem 152 salva com sucesso.
# Imagem 154 salva com sucesso.
# Imagem 156 salva com sucesso.
# Imagem 158 salva com sucesso.
# Imagem 160 salva com sucesso.
# Imagem 161 salva com sucesso.
# Imagem 162 salva com sucesso.
# Imagem 163 salva com sucesso.
# Imagem 164 salva com sucesso.
# Imagem 165 salva com sucesso.
# Imagem 166 salva com sucesso.
# Imagem 167 salva com sucesso.
# Imagem 168 salva com sucesso.
# Imagem 169 salva com sucesso.
# Imagem 170 salva com sucesso.
# Imagem 171 salva com sucesso.
# Imagem 172 salva com sucesso.
# Imagem 173 salva com sucesso.
# Imagem 174 salva com sucesso.
# Imagem 175 salva com sucesso.
